# %%
10 + 3
# Out:
# 13

# %%
2 * 3
# Out:
# 6

# %%
2 ** 3
# Out:
# 8

# %%
x = 12
x
# Out:
# 12

# %%
y = 15

# %%
x + y
# Out:
# 27

# %%
'Hola mundo'
# Out:
# 'Hola mundo'

# %%
x = 'Hola'
y = 'Mundo'
x + y
# Out:
# 'HolaMundo'

# %%
x + ' ' + y
# Out:
# 'Hola Mundo'

# %%
[1, 2, 3, 5, 6]
# Out:
# [1, 2, 3, 5, 6]

# %%
[1, 2, 3, 4] + [2, 3, 4]
# Out:
# [1, 2, 3, 4, 2, 3, 4]

# %%
lista = [1, 2, 3, 4, 5]

# %%
lista[0]
# Out:
# 1

# %%
lista[3]
# Out:
# 4

# %%
lista[-1]
# Out:
# 5

# %%
[1, 2, 3, 4] + [10]
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# np es un elemento que contiene una libreria para hacer analisis numérico:

# %%
import numpy as np

# %%
np.array([1, 2, 3, 4, 5])
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# Lo que hago es sumarle 10 a cada uno de los elementos de la lista:

# %%
np.array([1, 2, 3, 4, 5]) + 10
# Out:
# array([11, 12, 13, 14, 15])

# %% [markdown]
# Para saber las dimensiones de nuestro vector:

# %%
np.array([1, 2, 3, 4, 5]).shape
# Out:
# (5,)

# %%
np.array([[1, 2, 3, 4], [6, 7, 8, 9]])
# Out:
# array([[1, 2, 3, 4],
#        [6, 7, 8, 9]])

# %% [markdown]
# Nos muestra que tiene 2 dimensiones verticales y 4 dimensiones en la horizontal:

# %%
np.array([[1, 2, 3, 4], [6, 7, 8, 9]]).shape
# Out:
# (2, 4)

# %% [markdown]
# Con esto obtengo con 0 la primer lista y con 2 me meto en esa lista y obtengo 3:

# %%
np.array([[1, 2, 3, 4], [6, 7, 8, 9]])[0][2]
# Out:
# 3

# %% [markdown]
# Esto me carga la libreria de pandas

# %%
import pandas as pd

# %% [markdown]
# Con esto me va a mostrar en que indice se encuetra cada numero de la lista:

# %%
pd.Series([10, 9, 8, 7, 6])
# Out:
# 0    10
# 1     9
# 2     8
# 3     7
# 4     6
# dtype: int64

# %% [markdown]
# Guardo la lista anterior en una variable para ser mas comodo al requerir informacion:

# %%
sr = pd.Series([10, 9, 8, 7, 6]) 
sr
# Out:
# 0    10
# 1     9
# 2     8
# 3     7
# 4     6
# dtype: int64

# %%
sr.values
# Out:
# array([10,  9,  8,  7,  6])

# %%
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr.shape
# Out:
# (5,)

# %%
sr[3]
# Out:
# 7

# %% [markdown]
# Obtengo los numeros de los indices 0, 4, 2 y esto respeta el orden en que lo pongo:

# %%
sr[[0,4,2]]
# Out:
# 0    10
# 4     6
# 2     8
# dtype: int64

# %% [markdown]
# Obtengo un sistema de indices con letras:

# %%
sr = pd.Series([10, 9, 8, 7, 6], index = ['a','b','c','d','e',]) 
sr
# Out:
# a    10
# b     9
# c     8
# d     7
# e     6
# dtype: int64

# %%
sr ['c']
# Out:
# 8

# %%
sr [['c','d','e']]
# Out:
# c    8
# d    7
# e    6
# dtype: int64

# %%
sr['b':'e'] # aqui obtengo los datos de b a e
# Out:
# b    9
# c    8
# d    7
# e    6
# dtype: int64

# %%
dict_data = {'CO':100, 'MX':200, 'AR':300}
dict_data
# Out:
# {'AR': 300, 'CO': 100, 'MX': 200}

# %%
dict_data.keys() # obtengo solo llaves
# Out:
# dict_keys(['CO', 'MX', 'AR'])

# %%
dict_data['MX'] # obtengo el contenido de esa llave
# Out:
# 200

# %%
pd.Series(dict_data)
# Out:
# CO    100
# MX    200
# AR    300
# dtype: int64

# %% [markdown]
# Creamos una serie basada en nuestro diccionario en donde el indice esta definido por las llaves de nuestro diccionario y los valores de nuestra serie.
#
# Aparece NaN porque cambie el nombre de la llave de AR por PE

# %%
pd.Series(dict_data, index = ['CO','MX','PE'])
# Out:
# CO    100.0
# MX    200.0
# PE      NaN
# dtype: float64

# %%
import numpy as np

# %%
np.nan+10
# Out:
# nan

# %%
np.nan*10
# Out:
# nan

# %%
sr = pd.Series(dict_data, index = ['CO','MX','PE'])
sr
# Out:
# CO    100.0
# MX    200.0
# PE      NaN
# dtype: float64

# %% [markdown]
# Me marca donde está mi variable o valor nulo:

# %%
sr.isnull()
# Out:
# CO    False
# MX    False
# PE     True
# dtype: bool

# %% [markdown]
# Me marca las variables no nulas:

# %%
sr.notnull()
# Out:
# CO     True
# MX     True
# PE    False
# dtype: bool
